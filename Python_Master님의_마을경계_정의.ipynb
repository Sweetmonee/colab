# %% [markdown]
# <a href="https://colab.research.google.com/github/Sweetmonee/colab/blob/main/Python_Master%EB%8B%98%EC%9D%98_%EB%A7%88%EC%9D%84%EA%B2%BD%EA%B3%84_%EC%A0%95%EC%9D%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpd
from shapely.geometry import Point, Polygon, MultiPolygon

geodf = gpd.read_file('연속지적도/LSMD_CONT_LDREG_50_202210.shp', encoding='cp949').to_crs('EPSG:4326')
geodf
# Out:
#                         PNU      JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0       5011010100112750002    1275-2도    1   984588      50110
# 1       5011010100111300003   1130-3 도    1   985005      50110
# 2       5011010200101330020    133-20대    1   985301      50110
# 3       5011010100111060009    1106-9도    1   985164      50110
# 4       5011010100110940036   1094-36대    1   985259      50110
# ...                     ...        ...  ...      ...        ...
# 873872  5011011700129990003   2999-3 천    1  1036100      50110
# 873873  5011011700118750000      1875전    1  1355526      50110
# 873874  5011011700117530015  1753-15 과    1  1373910      50110
# 873875  5011013900128040000      2804도    1  1228111      50110
# 873876  5011013500113810000      1381천    1  2512190      50110
#
#                                                  geometry
# 0       POLYGON ((126.52556 33.51577, 126.52561 33.515...
# 1       POLYGON ((126.52889 33.51265, 126.52894 33.512...
# ...

# %%
import pandas as pd
geodf['PNU'] = pd.to_numeric(geodf['PNU'])

# %%
# geodf['BCHK'] = pd.to_numeric(geodf['BCHK'])

# %%
# geodf.BCHK.unique()
# Out:
# array([1, 3, 9, 8, 0, 2])

# %%
# geodf[geodf['BCHK'] == 2]
# Out:
#                         PNU      JIBUN  BCHK  SGG_OID COL_ADM_SE  \
# 845976  5013010100103120005    312-5 차     2  1993848      50130
# 845977  5013010100104380002    438-2 대     2  1993849      50130
# 845978  5013010800105680000      568 대     2  1993840      50130
# 845979  5013011100108260006    826-6 대     2  1993841      50130
# 845980  5013011400121790002   2179-2 과     2  1993799      50130
# 845981  5013011800118410000      1841임     2  1993837      50130
# 845982  5013025326109680000      968 대     2  1993844      50130
# 845983  5013025326114410010   1441-10과     2  1993806      50130
# 845984  5013025326114410054  1441-54 과     2  1993807      50130
# 845985  5013025925104190003    419-3 임     2  1993810      50130
# 845993  5013011800118410007   1841-7 임     2  1993838      50130
# 845994  5013011800200140004    산14-4 임     2  1993817      50130
# 845995  5013012100109380006    938-6 전     2  1993802      50130
# ...

# %%
# geodf.PNU.describe()
# Out:
# count    8.738770e+05
# mean     5.011826e+18
# std      4.923884e+15
# min      5.013025e+17
# 25%      5.011025e+18
# 50%      5.011026e+18
# 75%      5.013025e+18
# max      5.013032e+18
# Name: PNU, dtype: float64

# %%
# geodf[geodf['PNU'] // 10**14 == 5013]
# Out:
#                        PNU   JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 777618  501302532721710000  산171 도    9  1982376      50130
#
#                                                  geometry JB_tp slice1
# 777618  POLYGON ((126.64417 33.33404, 126.64421 33.334...  산171      도

# %%
# gapa = geodf[geodf['PNU'] // 10**9 == 5013025026].reset_index(drop = True)
# gapa
# Out:
#                       PNU    JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0     5013025026102910001  291-1 전    1  1990530      50130
# 1     5013025026105600006  560-6 대    1  1989968      50130
# 2     5013025026105600000     560대    1  1989967      50130
# 3     5013025026102910000     291전    1  1990529      50130
# 4     5013025026105970000     597임    1   769358      50130
# ...                   ...      ...  ...      ...        ...
# 1091  5013025026104280000     428임    1   934543      50130
# 1092  5013025026106840000     684잡    1   770655      50130
# 1093  5013025026105260001  526-1 잡    1   952833      50130
# 1094  5013025026103960000     396대    1   767083      50130
# 1095  5013025026103730002   373-2도    3   767930      50130
#
#                                                geometry
# 0     POLYGON ((126.27031 33.17066, 126.26988 33.170...
# 1     POLYGON ((126.27359 33.16603, 126.27362 33.166...
# 2     POLYGON ((126.27370 33.16591, 126.27368 33.165...
# ...

# %%
# gapa[gapa['PNU'] % 10**8 == 10000]
# Out:
# Empty GeoDataFrame
# Columns: [PNU, JIBUN, BCHK, SGG_OID, COL_ADM_SE, geometry]
# Index: []

# %%
hallim = geodf[geodf['PNU'] // 10**9 == 5011025021].reset_index(drop = True)
hallim
# Out:
#                       PNU      JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0     5011025021106910000       691전    1   987418      50110
# 1     5011025021118560000     1856 전    1  2533175      50110
# 2     5011025021132570002   3257-2 전    1  2295555      50110
# 3     5011025021100340014    34-14 대    1  2529656      50110
# 4     5011025021128580013  2858-13 대    1  2246545      50110
# ...                   ...        ...  ...      ...        ...
# 8521  5011025021135050000      3505전    1  2528121      50110
# 8522  5011025021135050001   3505-1 전    1  2528122      50110
# 8523  5011025021135050002   3505-2 전    1  2528123      50110
# 8524  5011025021111610000     1161 대    1  2528316      50110
# 8525  5011025021141470001    4147-1대    1  2528414      50110
#
#                                                geometry
# 0     POLYGON ((126.29924 33.43904, 126.29929 33.439...
# 1     POLYGON ((126.29203 33.42926, 126.29228 33.429...
# ...

# %%
hallim[hallim['PNU'] % 10**8 == 11790006]
# Out:
#                       PNU    JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 1292  5011025024111790006  1179-6대    1  1043404      50110
#
#                                                geometry
# 1292  POLYGON ((126.26812 33.41214, 126.26814 33.412...

# %%
hallim.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 5258 entries, 0 to 5257
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   PNU         5258 non-null   int64
#  1   JIBUN       5258 non-null   object
#  2   BCHK        5258 non-null   object
#  3   SGG_OID     5258 non-null   int64
#  4   COL_ADM_SE  5258 non-null   object
#  5   geometry    5258 non-null   geometry
# dtypes: geometry(1), int64(2), object(3)
# memory usage: 246.6+ KB

# %%
Hanlim_Guideok1 = pd.read_csv('./마을번지csv/한림읍 귀덕1리.csv', header = None)
Hanlim_Guideok1
# Out:
#             0
# 0    10060002
# 1    10030000
# 2    10080000
# 3    10120000
# 4    10100002
# ..        ...
# 340  10910000
# 341   6210000
# 342   6210002
# 343   6380001
# 344   6380002
#
# [345 rows x 1 columns]

# %%
Hanlim_Guideok1[0] = Hanlim_Guideok1[0].apply(lambda x : str(x).zfill(8))
Hanlim_Guideok1
# Out:
#             0
# 0    10060002
# 1    10030000
# 2    10080000
# 3    10120000
# 4    10100002
# ..        ...
# 340  10910000
# 341  06210000
# 342  06210002
# 343  06380001
# 344  06380002
#
# [345 rows x 1 columns]

# %%
Hanlim_Guideok1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 345 entries, 0 to 344
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       345 non-null    int64
# dtypes: int64(1)
# memory usage: 2.8 KB

# %%
Hanlim_Guideok1[0] = pd.to_numeric(Hanlim_Guideok1[0])
Hanlim_Guideok1
# Out:
#             0
# 0    10060002
# 1    10030000
# 2    10080000
# 3    10120000
# 4    10100002
# ..        ...
# 340  10910000
# 341   6210000
# 342   6210002
# 343   6380001
# 344   6380002
#
# [345 rows x 1 columns]

# %%
Hanlim_Guideok1list = []

for j in range(len(hallim)):
    for i in range(len(Hanlim_Guideok1)):
        if hallim['PNU'][j] % 10**8 == Hanlim_Guideok1[0][i]:
            Hanlim_Guideok1list.append(hallim.loc[j][:])

# %%
len(Hanlim_Guideok1list)
# Out:
# 244

# %%
Hanlim_Guideok1list
# Out:
# [PNU                                         5011025024112360006
#  JIBUN                                                  1236-6 임
#  BCHK                                                          1
#  SGG_OID                                                 1013350
#  COL_ADM_SE                                                50110
#  geometry      POLYGON ((126.26729596726565 33.41533671914344...
#  Name: 11, dtype: object,
#  PNU                                         5011025024108180000
#  JIBUN                                                      818묘
#  BCHK                                                          1
#  SGG_OID                                                 1044193
#  COL_ADM_SE                                                50110
#  geometry      POLYGON ((126.27499277358235 33.40760492479916...
#  Name: 123, dtype: object,
#  PNU                                         5011025024108160000
#  JIBUN                                                      816묘
# ...

# %%
Hanlim_Guideok1df = gpd.GeoDataFrame(Hanlim_Guideok1list, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
Hanlim_Guideok1df
# Out:
#                      PNU     JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0    5011025021110060002   1006-2대    1  1038478      50110
# 1    5011025021112360004  1236-4 대    1  1038487      50110
# 2    5011025021112360005   1236-5대    1  1038496      50110
# 3    5011025021111890000     1189대    1  1038575      50110
# 4    5011025021111900000     1190대    1  1038577      50110
# ..                   ...       ...  ...      ...        ...
# 239  5011025021113630001   1363-1대    1  2387029      50110
# 240  5011025021109570000     957 대    1  2361489      50110
# 241  5011025021110910000     1091대    1  2303910      50110
# 242  5011025021110910000     1091대    1  2303910      50110
# 243  5011025021110430000     1043대    1  2523357      50110
#
#                                               geometry
# 0    POLYGON ((126.29481 33.44410, 126.29489 33.444...
# 1    POLYGON ((126.29578 33.44402, 126.29580 33.444...
# 2    POLYGON ((126.29506 33.44391, 126.29528 33.443...
# ...

# %%
Hanlim_Guideok1df.set_geometry(col = 'geometry', inplace = True)

# %%
Hanlim_Guideok1df.to_file("마을 shp_old/귀덕1리.shp")

# %%
Entire_Viliage = pd.read_csv('./마을번지csv/마을경계코드정리.csv')
Entire_Viliage
# Out:
#            귀덕1리        귀덕2리       귀덕3리        신례1리      신례2리       신흥1리  \
# 0    10060002.0  30930000.0  2270003.0   9810000.0  150001.0   880000.0
# 1    10030000.0  30780000.0  2100000.0  10580000.0  260000.0   900003.0
# 2    10080000.0  30960000.0  2120000.0  10590000.0  260002.0   910000.0
# 3    10120000.0  31080005.0  2160000.0  11900000.0  260003.0  1120000.0
# 4    10100002.0  31090000.0  2190000.0  12510000.0  270001.0  1120001.0
# ..          ...         ...        ...         ...       ...        ...
# 565         NaN         NaN        NaN         NaN       NaN        NaN
# 566         NaN         NaN        NaN         NaN       NaN        NaN
# 567         NaN         NaN        NaN         NaN       NaN        NaN
# 568         NaN         NaN        NaN         NaN       NaN        NaN
# 569         NaN         NaN        NaN         NaN       NaN        NaN
#
#            신흥2리       수산1리        수산2리       삼달1리  ...        조일리         협재리  \
# ...

# %%
# 백록담 좌표 : 33.36, 126.53

# %%
Hanlim_Guideok2 = Entire_Viliage[['귀덕2리']]
Hanlim_Guideok2
# Out:
#            귀덕2리
# 0    30930000.0
# 1    30780000.0
# 2    30960000.0
# 3    31080005.0
# 4    31090000.0
# ..          ...
# 565         NaN
# 566         NaN
# 567         NaN
# 568         NaN
# 569         NaN
#
# [570 rows x 1 columns]

# %%
Hanlim_Guideok2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 570 entries, 0 to 569
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   귀덕2리    191 non-null    float64
# dtypes: float64(1)
# memory usage: 4.6 KB

# %%
Hanlim_Guideok2list = []

for j in range(len(hallim)):
    for i in range(len(Hanlim_Guideok2)):
        if hallim['PNU'][j] % 10**8 == Hanlim_Guideok2['귀덕2리'][i]:
            Hanlim_Guideok2list.append(hallim.loc[j][:])

# %%
len(Hanlim_Guideok2list)
# Out:
# 160

# %%
Hanlim_Guideok2listdf = gpd.GeoDataFrame(Hanlim_Guideok2list, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
Hanlim_Guideok2listdf
# Out:
#                      PNU    JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0    5011025021130960000    3096임    1  1038475      50110
# 1    5011025021130960000    3096임    1  1038475      50110
# 2    5011025021131460000    3146대    1  1038714      50110
# 3    5011025021131990001  3199-1대    1  1038721      50110
# 4    5011025021140470000    4047대    1  1038732      50110
# ..                   ...      ...  ...      ...        ...
# 155  5011025021138800000    3880대    1  2265041      50110
# 156  5011025021131910000    3191대    1  2350310      50110
# 157  5011025021139450000   3945 대    1  2527178      50110
# 158  5011025021141470001  4147-1대    1  2528414      50110
# 159  5011025021141470001  4147-1대    1  2528414      50110
#
#                                               geometry
# 0    POLYGON ((126.28512 33.44396, 126.28515 33.443...
# 1    POLYGON ((126.28512 33.44396, 126.28515 33.443...
# 2    POLYGON ((126.28249 33.44234, 126.28249 33.442...
# ...

# %%
Hanlim_Guideok2listdf.to_file("마을 shp_old/귀덕2리.shp")

# %%
Entire_Viliage['귀덕3리'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 570 entries, 0 to 569
# Series name: 귀덕3리
# Non-Null Count  Dtype
# --------------  -----
# 99 non-null     float64
# dtypes: float64(1)
# memory usage: 4.6 KB

# %%
Hanlim_Guideok3list = []

for j in range(len(hallim)):
    for i in range(len(Entire_Viliage)):
        if hallim['PNU'][j] % 10**8 == Entire_Viliage['귀덕3리'][i]:
            Hanlim_Guideok3list.append(hallim.loc[j][:])

# %%
len(Hanlim_Guideok3list)
# Out:
# 87

# %%
Hanlim_Guideok3listdf = gpd.GeoDataFrame(Hanlim_Guideok3list, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
Hanlim_Guideok3listdf
# Out:
#                     PNU    JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0   5011025021101180000     118대    1  1041492      50110
# 1   5011025021121870000    2187전    1  1041496      50110
# 2   5011025021121870003  2187-3대    1  1041497      50110
# 3   5011025021101190001   119-1창    1  1041499      50110
# 4   5011025021100830000      83대    1  1041503      50110
# ..                  ...      ...  ...      ...        ...
# 82  5011025021121530000    2153대    1  1451355      50110
# 83  5011025021101370000     137대    1  1451356      50110
# 84  5011025021121590001  2159-1대    1  1451359      50110
# 85  5011025021100820000      82대    1  1471622      50110
# 86  5011025021101670005  167-5 대    1  2403715      50110
#
#                                              geometry
# 0   POLYGON ((126.29712 33.41784, 126.29727 33.417...
# 1   POLYGON ((126.29615 33.41769, 126.29635 33.417...
# 2   POLYGON ((126.29635 33.41778, 126.29640 33.417...
# ...

# %%
Hanlim_Guideok3listdf.to_file("마을 shp_old/귀덕3리.shp")

# %%
han3list = []

for j in range(len(hallim)):
    for i in range(len(han123)):
        if hallim['PNU'][j] % 10**8 == han123['한림3리'][i]:
            han3list.append(hallim.loc[j][:])

# %%
len(han3list)
# Out:
# 32

# %%
han3df = gpd.GeoDataFrame(han3list, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
han3df
# Out:
#                     PNU  JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0   5011025024100500000   50 대    1  1001750      50110
# 1   5011025024100480000    48전    1  1043020      50110
# 2   5011025024100480000    48전    1  1043020      50110
# 3   5011025024100730000    73대    1  1043266      50110
# 4   5011025024100750000   75 대    1  1043291      50110
# 5   5011025024100860000    86대    1  1043313      50110
# 6   5011025024100810000    81전    1  1043341      50110
# 7   5011025024100930004  93-4대    1  1043553      50110
# 8   5011025024100340000    34대    1  1043119      50110
# 9   5011025024100350000   35 전    1  1043137      50110
# 10  5011025024100530000    53대    1  1043149      50110
# 11  5011025024100360000    36대    1  1207038      50110
# 12  5011025024100580000    58전    1  1237651      50110
# 13  5011025024100410000    41대    1  1237683      50110
# 14  5011025024100880000    88대    1  1329236      50110
# 15  5011025024100880000    88대    1  1329236      50110
# ...

# %%
han3df.to_file("마을 shp_old/한림3리.shp")

# %%
ri_geodf = gpd.read_file('제주도 리 shp/LSMD_ADM_SECT_RI_50.shp', encoding='cp949').to_crs('EPSG:4326')
ri_geodf
# Out:
#           RI_CD RI_NM  SGG_OID COL_ADM_SE    GID  \
# 0    5013025021   상모리      458      50130  15201
# 1    5013025026   가파리      456      50130  15202
# 2    5013025030   구억리      482      50130  15203
# 3    5013031025   사계리      455      50130  15204
# 4    5013031027   서광리      452      50130  15205
# ..          ...   ...      ...        ...    ...
# 117  5011025341  하귀2리      241      50110  15320
# 118  5011025034   월림리      240      50110  15321
# 119  5011025028   옹포리      239      50110  15322
# 120  5013025921   성산리     1461      50130  15472
# 121  5013025922   오조리     1463      50130  15473
#
#                                               geometry
# 0    POLYGON ((126.25517 33.22423, 126.25519 33.224...
# 1    MULTIPOLYGON (((126.26453 33.16963, 126.26454 ...
# 2    POLYGON ((126.27833 33.27464, 126.27841 33.274...
# 3    MULTIPOLYGON (((126.28410 33.23307, 126.28412 ...
# 4    POLYGON ((126.28206 33.30320, 126.28243 33.303...
# ...

# %%
ri_geodf[ri_geodf['RI_NM'] == '귀덕리']
# Out:
#          RI_CD RI_NM  SGG_OID COL_ADM_SE    GID  \
# 90  5011025021   귀덕리     1873      50110  15293
#
#                                              geometry
# 90  MULTIPOLYGON (((126.27319 33.43510, 126.27331 ...

# %%
# gang_geodf = gpd.read_file('마을 shp_new/강구리.shp', encoding='cp949').set_crs('EPSG:4326')
Hanlim_Guideok1_geodf = gpd.read_file('마을 shp_new/귀덕1리.shp', encoding='cp949').set_crs('EPSG:4326')
Hanlim_Guideok2_geodf = gpd.read_file('마을 shp_new/귀덕2리.shp', encoding='cp949').set_crs('EPSG:4326')
Hanlim_Guideok3_geodf = gpd.read_file('마을 shp_new/귀덕3리.shp', encoding='cp949').set_crs('EPSG:4326')

# %%
from folium.features import DivIcon
import folium

map = folium.Map(location=[33.412, 126.2712], tiles ='OpenStreetMap' ,zoom_start=15)
folium.GeoJson(ri_geodf.geometry.loc[90],
               style_function= lambda x : {'fillColor':'gray', 'fill_opacity':0.1, 'color':'gray', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(Hanlim_Guideok1_geodf.geometry,
               style_function= lambda x : {'fillColor':'navy', 'fill_opacity':0.1, 'color':'navy', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(Hanlim_Guideok2_geodf.geometry,
               style_function= lambda x : {'fillColor':'red', 'fill_opacity':0.1, 'color':'red', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(Hanlim_Guideok3_geodf.geometry,
               style_function= lambda x : {'fillColor':'green', 'fill_opacity':0.1, 'color':'green', 'weight':1.5}
              ).add_to(map)

# folium.GeoJson(han3_geodf.geometry,
#                style_function= lambda x : {'fillColor':'yellow', 'fill_opacity':0.1, 'color':'yellow', 'weight':1.5}
#               ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
Hyeobjae = geodf[geodf['PNU'] // 10**9 == 5011025031].reset_index(drop = True)
Hyeobjae
# Out:
#                       PNU     JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0     5011025031129760000     2976대    1   987745      50110
# 1     5011025031121290004  2129-4 임    1  2534429      50110
# 2     5011025031108420000      842임    1  2428317      50110
# 3     5011025031108420001   842-1 임    1  2428318      50110
# 4     5011025031114680001  1468-1 대    1  1000202      50110
# ...                   ...       ...  ...      ...        ...
# 5389  5011025031102430004    243-4도    1  1453571      50110
# 5390  5011025031104560001    456-1도    1  1423050      50110
# 5391  5011025031106100002   610-2 잡    1  2039670      50110
# 5392  5011025031108730000      873수    1  1331234      50110
# 5393  5011025031122170001   2217-1전    1  2527859      50110
#
#                                                geometry
# 0     POLYGON ((126.22815 33.40531, 126.22815 33.405...
# 1     POLYGON ((126.24638 33.38840, 126.24655 33.388...
# 2     POLYGON ((126.25039 33.37392, 126.25033 33.373...
# ...

# %%
Hyeobjae_Hyeobjae =  Entire_Viliage[['협재리']]
Hyeobjae_Biyang =  Entire_Viliage[['비양리']]
Hyeobjae_Biyang
# Out:
#          비양리
# 0    20000.0
# 1    30000.0
# 2    50000.0
# 3    60000.0
# 4    80000.0
# ..       ...
# 565      NaN
# 566      NaN
# 567      NaN
# 568      NaN
# 569      NaN
#
# [570 rows x 1 columns]

# %%
Hyeobjae_Hyeobjaelist = []

for j in range(len(Hyeobjae)):
    for i in range(len(Hyeobjae_Hyeobjae)):
        if Hyeobjae['PNU'][j] % 10**8 == Hyeobjae_Hyeobjae['협재리'][i]:
            Hyeobjae_Hyeobjaelist.append(Hyeobjae.loc[j][:])
Hyeobjae_Hyeobjaelist
# Out:
# [PNU                                         5011025031114370000
#  JIBUN                                                     1437대
#  BCHK                                                          1
#  SGG_OID                                                 2349009
#  COL_ADM_SE                                                50110
#  geometry      POLYGON ((126.24586581607035 33.39941703725029...
#  Name: 29, dtype: object,
#  PNU                                         5011025031117510006
#  JIBUN                                                   1751-6대
#  BCHK                                                          1
#  SGG_OID                                                 1057779
#  COL_ADM_SE                                                50110
#  geometry      POLYGON ((126.24068086173638 33.39353622844073...
#  Name: 321, dtype: object,
#  PNU                                         5011025031117510003
#  JIBUN                                                   1751-3대
# ...

# %%
Hyeobjae_Biyanglist = []

for j in range(len(Hyeobjae)):
    for i in range(len(Hyeobjae_Biyang)):
        if Hyeobjae['PNU'][j] % 10**8 == Hyeobjae_Biyang['비양리'][i]:
            Hyeobjae_Biyanglist.append(Hyeobjae.loc[j][:])
Hyeobjae_Biyanglist
# Out:
# [PNU                                         5011025031100230000
#  JIBUN                                                       23과
#  BCHK                                                          1
#  SGG_OID                                                 1057589
#  COL_ADM_SE                                                50110
#  geometry      POLYGON ((126.26009866256996 33.39056610094945...
#  Name: 400, dtype: object,
#  PNU                                         5011025031100030000
#  JIBUN                                                        3전
#  BCHK                                                          1
#  SGG_OID                                                 1057600
#  COL_ADM_SE                                                50110
#  geometry      POLYGON ((126.26195982943759 33.39070935749959...
#  Name: 409, dtype: object,
#  PNU                                         5011025031100170000
#  JIBUN                                                       17전
# ...

# %%
len(Hyeobjae_Biyanglist)
# Out:
# 13

# %%
Hyeobjae_Hyeobjaelistdf = gpd.GeoDataFrame(Hyeobjae_Hyeobjaelist, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
Hyeobjae_Hyeobjaelistdf
# Out:
#                      PNU     JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0    5011025031114370000     1437대    1  2349009      50110
# 1    5011025031117510006   1751-6대    1  1057779      50110
# 2    5011025031117510003   1751-3대    1  1057794      50110
# 3    5011025031124470012  2447-12임    1  1057836      50110
# 4    5011025031125160000     2516대    1  1057841      50110
# ..                   ...       ...  ...      ...        ...
# 219  5011025031117670000     1767대    1  2520685      50110
# 220  5011025031116000000    1600 대    1  2448779      50110
# 221  5011025031116070000    1607 대    1  2231857      50110
# 222  5011025031124380000     2438임    1  2520714      50110
# 223  5011025031124470003   2447-3대    1  1239615      50110
#
#                                               geometry
# 0    POLYGON ((126.24587 33.39942, 126.24587 33.399...
# 1    POLYGON ((126.24068 33.39354, 126.24072 33.393...
# 2    POLYGON ((126.24098 33.39345, 126.24104 33.393...
# ...

# %%
Hyeobjae_Biyanglistdf = gpd.GeoDataFrame(Hyeobjae_Biyanglist, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
Hyeobjae_Biyanglistdf
# Out:
#                     PNU JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0   5011025031100230000   23과    1  1057589      50110
# 1   5011025031100030000    3전    1  1057600      50110
# 2   5011025031100170000   17전    1  1057613      50110
# 3   5011025031100260000   26전    1  1057683      50110
# 4   5011025031100250000   25전    1  1209078      50110
# 5   5011025031100180000   18전    1  1239734      50110
# 6   5011025031100120000  12 대    1  1257769      50110
# 7   5011025031100050000    5과    1  1331377      50110
# 8   5011025031200060000   산6대    1  1331134      50110
# 9   5011025031100160000   16임    1  1362014      50110
# 10  5011025031100290000  29 대    1  1379592      50110
# 11  5011025031100200000  20 과    1  1392609      50110
# 12  5011025031100060000    6과    1  1453659      50110
#
#                                              geometry
# 0   POLYGON ((126.26010 33.39057, 126.26012 33.390...
# 1   POLYGON ((126.26196 33.39071, 126.26206 33.390...
# ...

# %%
Hyeobjae_Hyeobjaelistdf.to_file("마을 shp_old/협재리.shp")
Hyeobjae_Biyanglistdf.to_file("마을 shp_old/비양리.shp")

# %%
# gang_geodf = gpd.read_file('마을 shp_new/강구리.shp', encoding='cp949').set_crs('EPSG:4326')
Hyeobjae_Hyeobjaelistdf_geodf = gpd.read_file('마을 shp_new/협재리.shp', encoding='cp949').set_crs('EPSG:4326')
Hyeobjae_Biyanglistdf_geodf = gpd.read_file('마을 shp_new/비양리.shp', encoding='cp949').set_crs('EPSG:4326')
# Hanlim_Guideok3_geodf = gpd.read_file('마을 shp_new/귀덕3리.shp', encoding='cp949').set_crs('EPSG:4326')

# %%
ri_geodf[ri_geodf['RI_NM'] == '협재리']
# Out:
#          RI_CD RI_NM  SGG_OID COL_ADM_SE    GID  \
# 55  5011025031   협재리      229      50110  15258
#
#                                              geometry
# 55  MULTIPOLYGON (((126.23363 33.38862, 126.23416 ...

# %%
from folium.features import DivIcon
import folium

map = folium.Map(location=[33.412, 126.2712], tiles ='OpenStreetMap' ,zoom_start=15)
folium.GeoJson(ri_geodf.geometry.loc[55],
               style_function= lambda x : {'fillColor':'gray', 'fill_opacity':0.1, 'color':'gray', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(Hyeobjae_Hyeobjaelistdf_geodf.geometry,
               style_function= lambda x : {'fillColor':'navy', 'fill_opacity':0.1, 'color':'navy', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(Hyeobjae_Biyanglistdf_geodf.geometry,
               style_function= lambda x : {'fillColor':'red', 'fill_opacity':0.1, 'color':'red', 'weight':1.5}
              ).add_to(map)

# folium.GeoJson(Hanlim_Guideok3_geodf.geometry,
#                style_function= lambda x : {'fillColor':'green', 'fill_opacity':0.1, 'color':'green', 'weight':1.5}
#               ).add_to(map)

# folium.GeoJson(han3_geodf.geometry,
#                style_function= lambda x : {'fillColor':'yellow', 'fill_opacity':0.1, 'color':'yellow', 'weight':1.5}
#               ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
eoum = geodf[geodf['PNU'] // 10**9 == 5011025336].reset_index(drop = True)
eoum
# Out:
#                       PNU     JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0     5011025336128290001   2829-1임    1   987747      50110
# 1     5011025336128290006  2829-6 임    1   987748      50110
# 2     5011025336101320000      132임    1   990002      50110
# 3     5011025336128600001   2860-1전    1   989770      50110
# 4     5011025336119060001  1906-1 대    1  2535433      50110
# ...                   ...       ...  ...      ...        ...
# 7350  5011025336200110000      산11목    1  2529523      50110
# 7351  5011025336106630000      663임    1  1396858      50110
# 7352  5011025336113150000    1315 임    1  1561697      50110
# 7353  5011025336139020000     3902도    1  2518331      50110
# 7354  5011025336102730000      273임    1  2528212      50110
#
#                                                geometry
# 0     POLYGON ((126.33884 33.40800, 126.33875 33.408...
# 1     POLYGON ((126.33870 33.40767, 126.33875 33.408...
# 2     POLYGON ((126.36219 33.40555, 126.36227 33.405...
# ...

# %%
eoum1 =  Entire_Viliage[['어음1리']]
eoum2 =  Entire_Viliage[['어음2리']]
eoum2
# Out:
#            어음2리
# 0    29560000.0
# 1    29290000.0
# 2    29500000.0
# 3    29500001.0
# 4    29400000.0
# ..          ...
# 565         NaN
# 566         NaN
# 567         NaN
# 568         NaN
# 569         NaN
#
# [570 rows x 1 columns]

# %%
eoum1list = []

for j in range(len(eoum)):
    for i in range(len(eoum1)):
        if eoum['PNU'][j] % 10**8 == eoum1['어음1리'][i]:
            eoum1list.append(eoum.loc[j][:])
eoum1list
# Out:
# [PNU                                         5011025336136010000
#  JIBUN                                                     3601대
#  BCHK                                                          1
#  SGG_OID                                                 1085167
#  COL_ADM_SE                                                50110
#  geometry      POLYGON ((126.33120789756799 33.41890039793679...
#  Name: 123, dtype: object,
#  PNU                                         5011025336136090000
#  JIBUN                                                     3609대
#  BCHK                                                          1
#  SGG_OID                                                 1085249
#  COL_ADM_SE                                                50110
#  geometry      POLYGON ((126.33121732356415 33.41824013491792...
#  Name: 129, dtype: object,
#  PNU                                         5011025336136710000
#  JIBUN                                                     3671대
# ...

# %%
eoum2list = []

for j in range(len(eoum)):
    for i in range(len(eoum2)):
        if eoum['PNU'][j] % 10**8 == eoum2['어음2리'][i]:
            eoum2list.append(eoum.loc[j][:])
eoum2list
# Out:
# [PNU                                         5011025336120320000
#  JIBUN                                                     2032과
#  BCHK                                                          1
#  SGG_OID                                                 1086607
#  COL_ADM_SE                                                50110
#  geometry      POLYGON ((126.34062865963732 33.40232470518227...
#  Name: 545, dtype: object,
#  PNU                                         5011025336129830000
#  JIBUN                                                     2983대
#  BCHK                                                          1
#  SGG_OID                                                 1086563
#  COL_ADM_SE                                                50110
#  geometry      POLYGON ((126.33711374229881 33.40264608299031...
#  Name: 723, dtype: object,
#  PNU                                         5011025336129220000
#  JIBUN                                                     2922학
# ...

# %%
len(eoum1list)
# Out:
# 58

# %%
eoum1listdf = gpd.GeoDataFrame(eoum1list, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
eoum2listdf = gpd.GeoDataFrame(eoum2list, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
eoum2listdf
# Out:
#                     PNU    JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0   5011025336120320000    2032과    1  1086607      50110
# 1   5011025336129830000    2983대    1  1086563      50110
# 2   5011025336129220000    2922학    1  1086503      50110
# 3   5011025336129330000    2933종    1  1086439      50110
# 4   5011025336129170000    2917대    1  1086523      50110
# ..                  ...      ...  ...      ...        ...
# 57  5011025336130080001  3008-1대    1  1457915      50110
# 58  5011025336130570000    3057대    1  1457924      50110
# 59  5011025336130100000   3010 대    1  1886001      50110
# 60  5011025336129500000    2950대    1  2190162      50110
# 61  5011025336129230000   2923 대    1  2499817      50110
#
#                                              geometry
# 0   POLYGON ((126.34063 33.40232, 126.34072 33.402...
# 1   POLYGON ((126.33711 33.40265, 126.33708 33.402...
# 2   POLYGON ((126.33820 33.40350, 126.33839 33.403...
# ...

# %%
eoum1listdf.to_file("마을 shp_old/어음1리.shp")
eoum2listdf.to_file("마을 shp_old/어음2리.shp")

# %%
# gang_geodf = gpd.read_file('마을 shp_new/강구리.shp', encoding='cp949').set_crs('EPSG:4326')
eoum1listdf_geodf = gpd.read_file('마을 shp_new/어음1리.shp', encoding='cp949').set_crs('EPSG:4326')
eoum2listdf_geodf = gpd.read_file('마을 shp_new/어음2리.shp', encoding='cp949').set_crs('EPSG:4326')
# Hanlim_Guideok3_geodf = gpd.read_file('마을 shp_new/귀덕3리.shp', encoding='cp949').set_crs('EPSG:4326')

# %%
ri_geodf[ri_geodf['RI_NM'] == '어음리']
# Out:
#          RI_CD RI_NM  SGG_OID COL_ADM_SE    GID  \
# 68  5011025336   어음리      215      50110  15271
#
#                                              geometry
# 68  POLYGON ((126.43282 33.36028, 126.43232 33.359...

# %%
from folium.features import DivIcon
import folium

map = folium.Map(location=[33.412, 126.2712], tiles ='OpenStreetMap' ,zoom_start=15)
folium.GeoJson(ri_geodf.geometry.loc[68],
               style_function= lambda x : {'fillColor':'gray', 'fill_opacity':0.1, 'color':'gray', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(eoum1listdf_geodf.geometry,
               style_function= lambda x : {'fillColor':'navy', 'fill_opacity':0.1, 'color':'navy', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(eoum2listdf_geodf.geometry,
               style_function= lambda x : {'fillColor':'red', 'fill_opacity':0.1, 'color':'red', 'weight':1.5}
              ).add_to(map)

# folium.GeoJson(Hanlim_Guideok3_geodf.geometry,
#                style_function= lambda x : {'fillColor':'green', 'fill_opacity':0.1, 'color':'green', 'weight':1.5}
#               ).add_to(map)

# folium.GeoJson(han3_geodf.geometry,
#                style_function= lambda x : {'fillColor':'yellow', 'fill_opacity':0.1, 'color':'yellow', 'weight':1.5}
#               ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
sinum = geodf[geodf['PNU'] // 10**9 == 5011025326].reset_index(drop = True)
sinum
# Out:
#                       PNU     JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0     5011025326108810000      881전    1   992756      50110
# 1     5011025326108810001   881-1 전    1   992757      50110
# 2     5011025326108810003   881-3 전    1   992758      50110
# 3     5011025326108810004   881-4 전    1   992759      50110
# 4     5011025326127680010  2768-10전    1   998845      50110
# ...                   ...       ...  ...      ...        ...
# 7036  5011025326100370004    37-4 전    1  2527636      50110
# 7037  5011025326108010001    801-1대    1  2527887      50110
# 7038  5011025326108010003   801-3 대    1  2527888      50110
# 7039  5011025326130150002   3015-2전    1  2528054      50110
# 7040  5011025326130090004  3009-4 차    1  2528074      50110
#
#                                                geometry
# 0     POLYGON ((126.37386 33.47598, 126.37376 33.475...
# 1     POLYGON ((126.37394 33.47598, 126.37394 33.476...
# 2     POLYGON ((126.37386 33.47598, 126.37394 33.475...
# ...

# %%
sinum_sinum =  Entire_Viliage[['신엄리']]
sinum_joongum =  Entire_Viliage[['중엄리']]
sinum_youngheoung =  Entire_Viliage[['용흥리']]
sinum_sinum
# Out:
#             신엄리
# 0    10700000.0
# 1    10410000.0
# 2    10660001.0
# 3    10660003.0
# 4    10490000.0
# ..          ...
# 565         NaN
# 566         NaN
# 567         NaN
# 568         NaN
# 569         NaN
#
# [570 rows x 1 columns]

# %%
sinum_sinumlist = []

for j in range(len(sinum)):
    for i in range(len(sinum_sinum)):
        if sinum['PNU'][j] % 10**8 == sinum_sinum['신엄리'][i]:
            sinum_sinumlist.append(sinum.loc[j][:])
sinum_sinumlist
# Out:
# [PNU                                         5011025326113160008
#  JIBUN                                                   1316-8대
#  BCHK                                                          1
#  SGG_OID                                                 1070285
#  COL_ADM_SE                                                50110
#  geometry      POLYGON ((126.36870640691991 33.470684173137, ...
#  Name: 367, dtype: object,
#  PNU                                         5011025326113150001
#  JIBUN                                                   1315-1대
#  BCHK                                                          1
#  SGG_OID                                                 1070293
#  COL_ADM_SE                                                50110
#  geometry      POLYGON ((126.36794417448573 33.47059760558952...
#  Name: 374, dtype: object,
#  PNU                                         5011025326112920004
#  JIBUN                                                   1292-4대
# ...

# %%
sinum_joongumlist = []

for j in range(len(sinum)):
    for i in range(len(sinum_joongum)):
        if sinum['PNU'][j] % 10**8 == sinum_joongum['중엄리'][i]:
            sinum_joongumlist.append(sinum.loc[j][:])
sinum_joongumlist
# Out:
# [PNU                                         5011025326107610001
#  JIBUN                                                    761-1대
#  BCHK                                                          1
#  SGG_OID                                                 1069797
#  COL_ADM_SE                                                50110
#  geometry      POLYGON ((126.37462201103402 33.47415024575435...
#  Name: 50, dtype: object,
#  PNU                                         5011025326107800001
#  JIBUN                                                    780-1대
#  BCHK                                                          1
#  SGG_OID                                                 1069680
#  COL_ADM_SE                                                50110
#  geometry      POLYGON ((126.37316014321074 33.47477590123168...
#  Name: 55, dtype: object,
#  PNU                                         5011025326107800001
#  JIBUN                                                    780-1대
# ...

# %%
sinum_youngheounglist = []

for j in range(len(sinum)):
    for i in range(len(sinum_youngheoung)):
        if sinum['PNU'][j] % 10**8 == sinum_youngheoung['용흥리'][i]:
            sinum_youngheounglist.append(sinum.loc[j][:])
sinum_youngheounglist
# Out:
# [PNU                                         5011025326118180001
#  JIBUN                                                  1818-1 대
#  BCHK                                                          1
#  SGG_OID                                                 2508785
#  COL_ADM_SE                                                50110
#  geometry      POLYGON ((126.36963023432784 33.45857470685868...
#  Name: 13, dtype: object,
#  PNU                                         5011025326118710005
#  JIBUN                                                   1871-5도
#  BCHK                                                          1
#  SGG_OID                                                 1056858
#  COL_ADM_SE                                                50110
#  geometry      POLYGON ((126.37005671594314 33.45635614001171...
#  Name: 37, dtype: object,
#  PNU                                         5011025326116930001
#  JIBUN                                                   1693-1대
# ...

# %%
len(sinum_youngheounglist)
# Out:
# 80

# %%
sinum_sinumlisttdf = gpd.GeoDataFrame(sinum_sinumlist, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
sinum_joongumlistdf = gpd.GeoDataFrame(sinum_joongumlist, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
sinum_youngheounglistdf = gpd.GeoDataFrame(sinum_youngheounglist, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
sinum_youngheounglistdf
# Out:
#                     PNU      JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0   5011025326118180001   1818-1 대    1  2508785      50110
# 1   5011025326118710005    1871-5도    1  1056858      50110
# 2   5011025326116930001    1693-1대    1  1071039      50110
# 3   5011025326117310001    1731-1대    1  1071045      50110
# 4   5011025326121620000      2162대    1  1071052      50110
# ..                  ...        ...  ...      ...        ...
# 75  5011025326116900001    1690-1대    1  2410193      50110
# 76  5011025326116890001    1689-1대    1  2410197      50110
# 77  5011025326118050000      1805임    1  2511972      50110
# 78  5011025326118460011  1846-11 대    1  2486769      50110
# 79  5011025326116860004   1686-4 대    1  2410161      50110
#
#                                              geometry
# 0   POLYGON ((126.36963 33.45857, 126.36953 33.458...
# 1   POLYGON ((126.37006 33.45636, 126.37005 33.456...
# 2   POLYGON ((126.36681 33.46200, 126.36677 33.461...
# ...

# %%
sinum_sinumlisttdf.to_file("마을 shp_old/신엄리.shp")
sinum_joongumlistdf.to_file("마을 shp_old/중엄리.shp")
sinum_youngheounglistdf.to_file("마을 shp_old/용흥리.shp")

# %%
# gang_geodf = gpd.read_file('마을 shp_new/강구리.shp', encoding='cp949').set_crs('EPSG:4326')
sinum_sinumlisttdf_geodf = gpd.read_file('마을 shp_new/신엄리.shp', encoding='cp949').set_crs('EPSG:4326')
sinum_joongumlistdf_geodf = gpd.read_file('마을 shp_new/중엄리.shp', encoding='cp949').set_crs('EPSG:4326')
sinum_youngheounglistdf_geodf = gpd.read_file('마을 shp_new/용흥리.shp', encoding='cp949').set_crs('EPSG:4326')

# %%
ri_geodf[ri_geodf['RI_NM'] == '신엄리']
# Out:
#           RI_CD RI_NM  SGG_OID COL_ADM_SE    GID  \
# 116  5011025326   신엄리      242      50110  15319
#
#                                               geometry
# 116  MULTIPOLYGON (((126.38094 33.45794, 126.38086 ...

# %%
from folium.features import DivIcon
import folium

map = folium.Map(location=[33.412, 126.2712], tiles ='OpenStreetMap' ,zoom_start=15)
folium.GeoJson(ri_geodf.geometry.loc[116],
               style_function= lambda x : {'fillColor':'gray', 'fill_opacity':0.1, 'color':'gray', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(sinum_sinumlisttdf_geodf.geometry,
               style_function= lambda x : {'fillColor':'navy', 'fill_opacity':0.1, 'color':'navy', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(sinum_joongumlistdf_geodf.geometry,
               style_function= lambda x : {'fillColor':'red', 'fill_opacity':0.1, 'color':'red', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(sinum_youngheounglistdf_geodf.geometry,
               style_function= lambda x : {'fillColor':'green', 'fill_opacity':0.1, 'color':'green', 'weight':1.5}
              ).add_to(map)

# folium.GeoJson(han3_geodf.geometry,
#                style_function= lambda x : {'fillColor':'yellow', 'fill_opacity':0.1, 'color':'yellow', 'weight':1.5}
#               ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
goseong = geodf[geodf['PNU'] // 10**9 == 5011025329].reset_index(drop = True)
goseong
# Out:
#                       PNU      JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0     5011025329103790003    379-3 전    1   987731      50110
# 1     5011025329103800002     380-2과    1   987733      50110
# 2     5011025329113040015  1304-15 창    1  2528626      50110
# 3     5011025329201410007   산141-7 임    1   992283      50110
# 4     5011025329109250000       925임    1   992126      50110
# ...                   ...        ...  ...      ...        ...
# 4158  5011025329103930004     393-4도    1  1470623      50110
# 4159  5011025329102520005    252-5 도    1  1521365      50110
# 4160  5011025329103930012   393-12 도    1  1521368      50110
# 4161  5011025329103930007    393-7 도    1  1409738      50110
# 4162  5011025329113040021  1304-21 과    1  2527638      50110
#
#                                                geometry
# 0     POLYGON ((126.41768 33.46082, 126.41776 33.460...
# 1     POLYGON ((126.41879 33.46056, 126.41864 33.460...
# ...

# %%
goseong1 =  Entire_Viliage[['고성1리']]
goseong2 =  Entire_Viliage[['고성2리']]
goseong2
# Out:
#           고성2리
# 0    1360000.0
# 1    1370000.0
# 2    1380000.0
# 3    1380002.0
# 4    1420005.0
# ..         ...
# 565        NaN
# 566        NaN
# 567        NaN
# 568        NaN
# 569        NaN
#
# [570 rows x 1 columns]

# %%
goseong1list = []

for j in range(len(goseong)):
    for i in range(len(goseong1)):
        if goseong['PNU'][j] % 10**8 == goseong1['고성1리'][i]:
            goseong1list.append(goseong.loc[j][:])
goseong1list
# Out:
# [PNU                                         5011025329105320001
#  JIBUN                                                    532-1대
#  BCHK                                                          1
#  SGG_OID                                                 2532320
#  COL_ADM_SE                                                50110
#  geometry      POLYGON ((126.4192823101773 33.45537399171165,...
#  Name: 19, dtype: object,
#  PNU                                         5011025329114940002
#  JIBUN                                                   1494-2대
#  BCHK                                                          1
#  SGG_OID                                                 1074657
#  COL_ADM_SE                                                50110
#  geometry      POLYGON ((126.41226033245161 33.4652000795434,...
#  Name: 169, dtype: object,
#  PNU                                         5011025329114940010
#  JIBUN                                                  1494-10대
# ...

# %%
goseong2list = []

for j in range(len(goseong)):
    for i in range(len(goseong2)):
        if goseong['PNU'][j] % 10**8 == goseong2['고성2리'][i]:
            goseong2list.append(goseong.loc[j][:])
goseong2list
# Out:
# [PNU                                         5011025329101350004
#  JIBUN                                                    135-4대
#  BCHK                                                          1
#  SGG_OID                                                 1067562
#  COL_ADM_SE                                                50110
#  geometry      POLYGON ((126.42681054081068 33.43528649245358...
#  Name: 55, dtype: object,
#  PNU                                         5011025329109200007
#  JIBUN                                                    920-7대
#  BCHK                                                          1
#  SGG_OID                                                 1069122
#  COL_ADM_SE                                                50110
#  geometry      POLYGON ((126.42487841967538 33.43584994783692...
#  Name: 61, dtype: object,
#  PNU                                         5011025329100950004
#  JIBUN                                                     95-4대
# ...

# %%
len(goseong2list)
# Out:
# 120

# %%
goseong1listdf = gpd.GeoDataFrame(goseong1list, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
goseong2listdf = gpd.GeoDataFrame(goseong2list, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
goseong2listdf
# Out:
#                      PNU    JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0    5011025329101350004   135-4대    1  1067562      50110
# 1    5011025329109200007   920-7대    1  1069122      50110
# 2    5011025329100950004    95-4대    1  1071677      50110
# 3    5011025329201260002  산126-2임    1  1075968      50110
# 4    5011025329201260000    산126임    1  1075970      50110
# ..                   ...      ...  ...      ...        ...
# 115  5011025329100940000      94학    1  2014994      50110
# 116  5011025329201470000    산147천    1  1795955      50110
# 117  5011025329201100000    산110임    1  1851055      50110
# 118  5011025329101350002  135-2 대    1  2223249      50110
# 119  5011025329109200006  920-6 대    1  2410073      50110
#
#                                               geometry
# 0    POLYGON ((126.42681 33.43529, 126.42690 33.435...
# 1    POLYGON ((126.42488 33.43585, 126.42484 33.435...
# 2    POLYGON ((126.42730 33.43338, 126.42711 33.433...
# ...

# %%
goseong1listdf.to_file("마을 shp_old/고성1리.shp")
goseong2listdf.to_file("마을 shp_old/고성2리.shp")

# %%
# gang_geodf = gpd.read_file('마을 shp_new/강구리.shp', encoding='cp949').set_crs('EPSG:4326')
goseong1listdf_geodf = gpd.read_file('마을 shp_new/고성1리.shp', encoding='cp949').set_crs('EPSG:4326')
goseong2listdf_geodf = gpd.read_file('마을 shp_new/고성2리.shp', encoding='cp949').set_crs('EPSG:4326')
# Hanlim_Guideok3_geodf = gpd.read_file('마을 shp_new/귀덕3리.shp', encoding='cp949').set_crs('EPSG:4326')

# %%
ri_geodf[ri_geodf['RI_NM'] == '고성리']
# Out:
#          RI_CD RI_NM  SGG_OID COL_ADM_SE    GID  \
# 40  5013025924   고성리      466      50130  15242
# 77  5011025329   고성리      206      50110  15280
#
#                                              geometry
# 40  MULTIPOLYGON (((126.88319 33.42857, 126.88327 ...
# 77  POLYGON ((126.41964 33.46523, 126.41993 33.465...

# %%
from folium.features import DivIcon
import folium

map = folium.Map(location=[33.412, 126.2712], tiles ='OpenStreetMap' ,zoom_start=15)
folium.GeoJson(ri_geodf.geometry.loc[77],
               style_function= lambda x : {'fillColor':'gray', 'fill_opacity':0.1, 'color':'gray', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(goseong1listdf_geodf.geometry,
               style_function= lambda x : {'fillColor':'navy', 'fill_opacity':0.1, 'color':'navy', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(goseong2listdf_geodf.geometry,
               style_function= lambda x : {'fillColor':'red', 'fill_opacity':0.1, 'color':'red', 'weight':1.5}
              ).add_to(map)

# folium.GeoJson(Hanlim_Guideok3_geodf.geometry,
#                style_function= lambda x : {'fillColor':'green', 'fill_opacity':0.1, 'color':'green', 'weight':1.5}
#               ).add_to(map)

# folium.GeoJson(han3_geodf.geometry,
#                style_function= lambda x : {'fillColor':'yellow', 'fill_opacity':0.1, 'color':'yellow', 'weight':1.5}
#               ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
gwangryeong = geodf[geodf['PNU'] // 10**9 == 5011025321
                   ].reset_index(drop = True)
gwangryeong
# Out:
#                        PNU      JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0      5011025321139700001   3970-1 과    1   987739      50110
# 1      5011025321139920001   3992-1 전    1   987740      50110
# 2      5011025321140550011  4055-11 전    1   987746      50110
# 3      5011025321116160001   1616-1 과    1  2537849      50110
# 4      5011025321119490006   1949-6 대    1  2533178      50110
# ...                    ...        ...  ...      ...        ...
# 10189  5011025321128260001    2826-1임    1  2527885      50110
# 10190  5011025321128290000      2829임    1  2527878      50110
# 10191  5011025321124160001   2416-1 대    1  2427987      50110
# 10192  5011025321122740004   2274-4 대    1  2528072      50110
# 10193  5011025321111220000     1122 대    1  2528264      50110
#
#                                                 geometry
# 0      POLYGON ((126.42327 33.45530, 126.42313 33.455...
# 1      POLYGON ((126.42207 33.45784, 126.42214 33.457...
# ...

# %%
gwangryeong1 =  Entire_Viliage[['광령1리']]
gwangryeong2 =  Entire_Viliage[['광령2리']]
gwangryeong3 =  Entire_Viliage[['광령3리']]
gwangryeong3
# Out:
#            광령3리
# 0    37750000.0
# 1    33750000.0
# 2    38050000.0
# 3    38530000.0
# 4    39530005.0
# ..          ...
# 565         NaN
# 566         NaN
# 567         NaN
# 568         NaN
# 569         NaN
#
# [570 rows x 1 columns]

# %%
gwangryeong1list = []
gwangryeong2list = []
gwangryeong3list = []

for j in range(len(gwangryeong)):
    for i in range(len(gwangryeong1)):
        if gwangryeong['PNU'][j] % 10**8 == gwangryeong1['광령1리'][i]:
            gwangryeong1list.append(gwangryeong.loc[j][:])
            
for j in range(len(gwangryeong)):
    for i in range(len(gwangryeong2)):
        if gwangryeong['PNU'][j] % 10**8 == gwangryeong2['광령2리'][i]:
            gwangryeong2list.append(gwangryeong.loc[j][:])
            
for j in range(len(gwangryeong)):
    for i in range(len(gwangryeong3)):
        if gwangryeong['PNU'][j] % 10**8 == gwangryeong3['광령3리'][i]:
            gwangryeong3list.append(gwangryeong.loc[j][:])

# %%
len(gwangryeong3list)
# Out:
# 51

# %%
gwangryeong1listdf = gpd.GeoDataFrame(gwangryeong1list, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
gwangryeong2listdf = gpd.GeoDataFrame(gwangryeong2list, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
gwangryeong3listdf = gpd.GeoDataFrame(gwangryeong3list, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
gwangryeong3listdf
# Out:
#                     PNU     JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0   5011025321138000005   3800-5대    1  1046071      50110
# 1   5011025321133750000     3375대    1  1160589      50110
# 2   5011025321133870001   3387-1대    1  1160717      50110
# 3   5011025321133870001   3387-1대    1  1160717      50110
# 4   5011025321138530007   3853-7대    1  1161202      50110
# 5   5011025321138430002   3843-2대    1  1161339      50110
# 6   5011025321138490003   3849-3대    1  1161233      50110
# 7   5011025321138500001   3850-1대    1  1161254      50110
# 8   5011025321138610002   3861-2대    1  1161258      50110
# 9   5011025321138520000     3852과    1  1161268      50110
# 10  5011025321138080001   3808-1대    1  1165281      50110
# 11  5011025321138000001   3800-1대    1  1165163      50110
# 12  5011025321137560000     3756대    1  1165386      50110
# 13  5011025321138040000     3804대    1  1165183      50110
# 14  5011025321137570009   3757-9대    1  1165408      50110
# ...

# %%
gwangryeong1listdf.to_file("마을 shp_old/광령1리.shp")
gwangryeong2listdf.to_file("마을 shp_old/광령2리.shp")
gwangryeong3listdf.to_file("마을 shp_old/광령3리.shp")

# %%
gwangryeong1listdf_geodf = gpd.read_file('마을 shp_new/광령1리.shp', encoding='cp949').set_crs('EPSG:4326')
gwangryeong2listdf_geodf = gpd.read_file('마을 shp_new/광령2리.shp', encoding='cp949').set_crs('EPSG:4326')
gwangryeong3listdf_geodf = gpd.read_file('마을 shp_new/광령3리.shp', encoding='cp949').set_crs('EPSG:4326')
# Hanlim_Guideok3_geodf = gpd.read_file('마을 shp_new/귀덕3리.shp', encoding='cp949').set_crs('EPSG:4326')

# %%
ri_geodf[ri_geodf['RI_NM'] == '광령리']
# Out:
#          RI_CD RI_NM  SGG_OID COL_ADM_SE    GID  \
# 79  5011025321   광령리      204      50110  15282
#
#                                              geometry
# 79  POLYGON ((126.44921 33.35908, 126.44867 33.360...

# %%
from folium.features import DivIcon
import folium

map = folium.Map(location=[33.412, 126.2712], tiles ='OpenStreetMap' ,zoom_start=15)
folium.GeoJson(ri_geodf.geometry.loc[79],
               style_function= lambda x : {'fillColor':'gray', 'fill_opacity':0.1, 'color':'gray', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(gwangryeong1listdf_geodf.geometry,
               style_function= lambda x : {'fillColor':'navy', 'fill_opacity':0.1, 'color':'navy', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(gwangryeong2listdf_geodf.geometry,
               style_function= lambda x : {'fillColor':'red', 'fill_opacity':0.1, 'color':'red', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(gwangryeong3listdf_geodf.geometry,
               style_function= lambda x : {'fillColor':'green', 'fill_opacity':0.1, 'color':'green', 'weight':1.5}
              ).add_to(map)

# folium.GeoJson(han3_geodf.geometry,
#                style_function= lambda x : {'fillColor':'yellow', 'fill_opacity':0.1, 'color':'yellow', 'weight':1.5}
#               ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
sunheul = geodf[geodf['PNU'] // 10**9 == 5011025930].reset_index(drop = True)
sunheul
# Out:
#                       PNU      JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0     5011025930126530004   2653-4 과    1   994055      50110
# 1     5011025930119500000     1950 잡    1   997156      50110
# 2     5011025930119500008   1950-8 잡    1   997163      50110
# 3     5011025930120670011  2067-11 전    1   995331      50110
# 4     5011025930119560007   1956-7 목    1  1000738      50110
# ...                   ...        ...  ...      ...        ...
# 9645  5011025930201830000      산183도    1  1146368      50110
# 9646  5011025930138570000      3857임    1  2528105      50110
# 9647  5011025930138570001   3857-1 도    1  2528106      50110
# 9648  5011025930138560000      3856과    1  2528332      50110
# 9649  5011025930138560003   3856-3 도    1  2528336      50110
#
#                                                geometry
# 0     POLYGON ((126.69930 33.51414, 126.69918 33.514...
# 1     POLYGON ((126.70427 33.46025, 126.70409 33.460...
# ...

# %%
sunheul1 =  Entire_Viliage[['선흘1리']]
sunheul2 =  Entire_Viliage[['선흘2리']]
sunheul2
# Out:
#            선흘2리
# 0    19480005.0
# 1    19470015.0
# 2    19470009.0
# 3    19470006.0
# 4    19470005.0
# ..          ...
# 565         NaN
# 566         NaN
# 567         NaN
# 568         NaN
# 569         NaN
#
# [570 rows x 1 columns]

# %%
sunheul1list = []
sunheul2list = []

for j in range(len(sunheul)):
    for i in range(len(sunheul1)):
        if sunheul['PNU'][j] % 10**8 == sunheul1['선흘1리'][i]:
            sunheul1list.append(sunheul.loc[j][:])
            
for j in range(len(sunheul)):
    for i in range(len(sunheul2)):
        if sunheul['PNU'][j] % 10**8 == sunheul2['선흘2리'][i]:
            sunheul2list.append(sunheul.loc[j][:])

# %%
len(sunheul2list)
# Out:
# 72

# %%
sunheul1listdf = gpd.GeoDataFrame(sunheul1list, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
sunheul2listdf = gpd.GeoDataFrame(sunheul2list, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
sunheul1listdf
# Out:
#                      PNU     JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0    5011025930111590001  1159-1 도    1  1053699      50110
# 1    5011025930126350000     2635대    1  1060497      50110
# 2    5011025930200600000      산60목    1  1435667      50110
# 3    5011025930132680001   3268-1대    1  2149106      50110
# 4    5011025930127330006   2733-6대    1  1120760      50110
# ..                   ...       ...  ...      ...        ...
# 149  5011025930111210000    1121 대    1  1541745      50110
# 150  5011025930111110001  1111-1 대    1  2303492      50110
# 151  5011025930111310001  1131-1 대    1  1979030      50110
# 152  5011025930126370002   2637-2대    1  1775530      50110
# 153  5011025930103370009    337-9잡    1  2277861      50110
#
#                                               geometry
# 0    POLYGON ((126.70823 33.51201, 126.70818 33.511...
# 1    POLYGON ((126.70424 33.51454, 126.70426 33.514...
# 2    POLYGON ((126.70418 33.49423, 126.70427 33.494...
# ...

# %%
sunheul1listdf.to_file("마을 shp_old/선흘1리.shp")
sunheul2listdf.to_file("마을 shp_old/선흘2리.shp")

# %%
# gang_geodf = gpd.read_file('마을 shp_new/강구리.shp', encoding='cp949').set_crs('EPSG:4326')
sunheul1listdf = gpd.read_file('마을 shp_new/선흘1리.shp', encoding='cp949').set_crs('EPSG:4326')
sunheul2listdf = gpd.read_file('마을 shp_new/선흘2리.shp', encoding='cp949').set_crs('EPSG:4326')
# Hanlim_Guideok3_geodf = gpd.read_file('마을 shp_new/귀덕3리.shp', encoding='cp949').set_crs('EPSG:4326')

# %%
ri_geodf[ri_geodf['RI_NM'] == '선흘리']
# Out:
#          RI_CD RI_NM  SGG_OID COL_ADM_SE    GID  \
# 86  5011025930   선흘리      197      50110  15289
#
#                                              geometry
# 86  POLYGON ((126.68130 33.45133, 126.68147 33.451...

# %%
from folium.features import DivIcon
import folium

map = folium.Map(location=[33.412, 126.2712], tiles ='OpenStreetMap' ,zoom_start=15)
folium.GeoJson(ri_geodf.geometry.loc[86],
               style_function= lambda x : {'fillColor':'gray', 'fill_opacity':0.1, 'color':'gray', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(sunheul1listdf.geometry,
               style_function= lambda x : {'fillColor':'navy', 'fill_opacity':0.1, 'color':'navy', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(sunheul2listdf.geometry,
               style_function= lambda x : {'fillColor':'red', 'fill_opacity':0.1, 'color':'red', 'weight':1.5}
              ).add_to(map)

# folium.GeoJson(Hanlim_Guideok3_geodf.geometry,
#                style_function= lambda x : {'fillColor':'green', 'fill_opacity':0.1, 'color':'green', 'weight':1.5}
#               ).add_to(map)

# folium.GeoJson(han3_geodf.geometry,
#                style_function= lambda x : {'fillColor':'yellow', 'fill_opacity':0.1, 'color':'yellow', 'weight':1.5}
#               ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
daeheul = geodf[geodf['PNU'] // 10**9 == 5011025926].reset_index(drop = True)
daeheul
# Out:
#                       PNU      JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0     5011025926101010004    101-4 과    1  2528608      50110
# 1     5011025926111480055  1148-55 대    1  2528609      50110
# 2     5011025926111480056  1148-56 대    1  2528611      50110
# 3     5011025926122220003   2222-3 도    1   992214      50110
# 4     5011025926101010002    101-2 대    1  2538117      50110
# ...                   ...        ...  ...      ...        ...
# 6338  5011025926122520007   2252-7 전    1  2527780      50110
# 6339  5011025926114600000     1460 창    1  2528076      50110
# 6340  5011025926200010002     산1-2 임    1  2528065      50110
# 6341  5011025926200010003     산1-3 임    1  2528064      50110
# 6342  5011025926200010005     산1-5 임    1  2528066      50110
#
#                                                geometry
# 0     POLYGON ((126.67274 33.51572, 126.67276 33.515...
# 1     POLYGON ((126.66781 33.48920, 126.66784 33.489...
# ...

# %%
daeheul1 =  Entire_Viliage[['대흘1리']]
daeheul2 =  Entire_Viliage[['대흘2리']]
daeheul2
# Out:
#           대흘2리
# 0    5080000.0
# 1    5130000.0
# 2    5180000.0
# 3    5170000.0
# 4    5650000.0
# ..         ...
# 565        NaN
# 566        NaN
# 567        NaN
# 568        NaN
# 569        NaN
#
# [570 rows x 1 columns]

# %%
daeheul1list = []
daeheul2list = []

for j in range(len(daeheul)):
    for i in range(len(daeheul1)):
        if daeheul['PNU'][j] % 10**8 == daeheul1['대흘1리'][i]:
            daeheul1list.append(daeheul.loc[j][:])
            
for j in range(len(daeheul)):
    for i in range(len(daeheul2)):
        if daeheul['PNU'][j] % 10**8 == daeheul2['대흘2리'][i]:
            daeheul2list.append(daeheul.loc[j][:])

# %%
len(daeheul2list)
# Out:
# 59

# %%
daeheul1listdf = gpd.GeoDataFrame(daeheul1list, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
daeheul2listdf = gpd.GeoDataFrame(daeheul2list, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
daeheul1listdf
# Out:
#                     PNU     JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0   5011025926116790002   1679-2대    1  1138553      50110
# 1   5011025926122390001   2239-1대    1  1138559      50110
# 2   5011025926122350003   2235-3대    1  1138561      50110
# 3   5011025926116860000     1686전    1  1138565      50110
# 4   5011025926123010002   2301-2대    1  1138673      50110
# 5   5011025926122740001   2274-1대    1  1138781      50110
# 6   5011025926122730001   2273-1대    1  1138795      50110
# 7   5011025926122980000     2298대    1  1138678      50110
# 8   5011025926117180000     1718대    1  1138440      50110
# 9   5011025926117770000     1777대    1  1138451      50110
# 10  5011025926122330000     2233대    1  1138467      50110
# 11  5011025926117140000     1714대    1  1138469      50110
# 12  5011025926117790000     1779대    1  1138470      50110
# 13  5011025926115970000     1597대    1  1138624      50110
# 14  5011025926109090000      909과    1  1138286      50110
# ...

# %%
daeheul1listdf.to_file("마을 shp_old/대흘1리.shp")
daeheul2listdf.to_file("마을 shp_old/대흘2리.shp")

# %%
# gang_geodf = gpd.read_file('마을 shp_new/강구리.shp', encoding='cp949').set_crs('EPSG:4326')
daeheul1listdf_geodf = gpd.read_file('마을 shp_new/대흘1리.shp', encoding='cp949').set_crs('EPSG:4326')
daeheul2listdf_geodf = gpd.read_file('마을 shp_new/대흘2리.shp', encoding='cp949').set_crs('EPSG:4326')
# Hanlim_Guideok3_geodf = gpd.read_file('마을 shp_new/귀덕3리.shp', encoding='cp949').set_crs('EPSG:4326')

# %%
ri_geodf[ri_geodf['RI_NM'] == '대흘리']
# Out:
#          RI_CD RI_NM  SGG_OID COL_ADM_SE    GID  \
# 85  5011025926   대흘리      198      50110  15288
#
#                                              geometry
# 85  POLYGON ((126.66153 33.45515, 126.66183 33.455...

# %%
from folium.features import DivIcon
import folium

map = folium.Map(location=[33.412, 126.2712], tiles ='OpenStreetMap' ,zoom_start=15)
folium.GeoJson(ri_geodf.geometry.loc[85],
               style_function= lambda x : {'fillColor':'gray', 'fill_opacity':0.1, 'color':'gray', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(daeheul1listdf_geodf.geometry,
               style_function= lambda x : {'fillColor':'navy', 'fill_opacity':0.1, 'color':'navy', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(daeheul2listdf_geodf.geometry,
               style_function= lambda x : {'fillColor':'red', 'fill_opacity':0.1, 'color':'red', 'weight':1.5}
              ).add_to(map)

# folium.GeoJson(Hanlim_Guideok3_geodf.geometry,
#                style_function= lambda x : {'fillColor':'green', 'fill_opacity':0.1, 'color':'green', 'weight':1.5}
#               ).add_to(map)

# folium.GeoJson(han3_geodf.geometry,
#                style_function= lambda x : {'fillColor':'yellow', 'fill_opacity':0.1, 'color':'yellow', 'weight':1.5}
#               ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
domo = geodf[geodf['PNU'] // 10**9 == 5011031027].reset_index(drop = True)
domo
# Out:
#                       PNU    JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0     5011031027105060000    506 임    1  2528524      50110
# 1     5011031027105060002  506-2 임    1  2528525      50110
# 2     5011031027104310002   431-2도    1  1162427      50110
# 3     5011031027104290002   429-2도    1  1162395      50110
# 4     5011031027104300002   430-2도    1  1162410      50110
# ...                   ...      ...  ...      ...        ...
# 6324  5011031027111890000   1189 과    1  2528103      50110
# 6325  5011031027111500000   1150 대    1  2528104      50110
# 6326  5011031027125460001  2546-1전    1  2528301      50110
# 6327  5011031027107680005  768-5 전    1  2528314      50110
# 6328  5011031027125470001  2547-1전    1  2528352      50110
#
#                                                geometry
# 0     POLYGON ((126.19996 33.34175, 126.19985 33.341...
# 1     POLYGON ((126.19996 33.34175, 126.19996 33.341...
# 2     POLYGON ((126.19623 33.34392, 126.19630 33.343...
# ...

# %%
domo_domo =  Entire_Viliage[['두모리']]
domo_hanwon =  Entire_Viliage[['한원리']]
domo_hanwon
# Out:
#             한원리
# 0    18490000.0
# 1    18550000.0
# 2    15000000.0
# 3    14240000.0
# 4    14260000.0
# ..          ...
# 565         NaN
# 566         NaN
# 567         NaN
# 568         NaN
# 569         NaN
#
# [570 rows x 1 columns]

# %%
domo_domolist = []
domo_hanwonlist = []

for j in range(len(domo)):
    for i in range(len(domo_domo)):
        if domo['PNU'][j] % 10**8 == domo_domo['두모리'][i]:
            domo_domolist.append(domo.loc[j][:])
            
for j in range(len(domo)):
    for i in range(len(domo_hanwon)):
        if domo['PNU'][j] % 10**8 == domo_hanwon['한원리'][i]:
            domo_hanwonlist.append(domo.loc[j][:])

# %%
len(domo_hanwonlist)
# Out:
# 66

# %%
domo_domolistdf = gpd.GeoDataFrame(domo_domolist, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
domo_hanwonlistdf = gpd.GeoDataFrame(domo_hanwonlist, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
domo_hanwonlistdf
# Out:
#                     PNU    JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0   5011031027114160000    1416대    1  1163040      50110
# 1   5011031027114140002  1414-2도    1  1163076      50110
# 2   5011031027114190000    1419대    1  1163080      50110
# 3   5011031027114170000    1417대    1  1163082      50110
# 4   5011031027114100000    1410전    1  1163113      50110
# ..                  ...      ...  ...      ...        ...
# 61  5011031027113960000    1396대    1  2516302      50110
# 62  5011031027113260000    1326대    1  2533812      50110
# 63  5011031027113260000    1326대    1  2533812      50110
# 64  5011031027115250001  1525-1임    1  2527647      50110
# 65  5011031027115250001  1525-1임    1  2527647      50110
#
#                                              geometry
# 0   POLYGON ((126.19562 33.33697, 126.19567 33.336...
# 1   POLYGON ((126.19530 33.33677, 126.19522 33.336...
# 2   POLYGON ((126.19603 33.33669, 126.19605 33.336...
# ...

# %%
domo_domolistdf.to_file("마을 shp_old/두모리.shp")
domo_hanwonlistdf.to_file("마을 shp_old/한원리.shp")

# %%
domo_domolistdf_geodf = gpd.read_file('마을 shp_new/두모리.shp', encoding='cp949').set_crs('EPSG:4326')
domo_hanwonlistdf_geodf = gpd.read_file('마을 shp_new/한원리.shp', encoding='cp949').set_crs('EPSG:4326')

# %%
ri_geodf[ri_geodf['RI_NM'] == '두모리']
# Out:
#          RI_CD RI_NM  SGG_OID COL_ADM_SE    GID  \
# 59  5011031027   두모리      225      50110  15262
#
#                                              geometry
# 59  POLYGON ((126.18087 33.35103, 126.18087 33.351...

# %%
from folium.features import DivIcon
import folium

map = folium.Map(location=[33.412, 126.2712], tiles ='OpenStreetMap' ,zoom_start=15)
folium.GeoJson(ri_geodf.geometry.loc[59],
               style_function= lambda x : {'fillColor':'gray', 'fill_opacity':0.1, 'color':'gray', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(domo_domolistdf_geodf.geometry,
               style_function= lambda x : {'fillColor':'navy', 'fill_opacity':0.1, 'color':'navy', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(domo_hanwonlistdf_geodf.geometry,
               style_function= lambda x : {'fillColor':'red', 'fill_opacity':0.1, 'color':'red', 'weight':1.5}
              ).add_to(map)

# folium.GeoJson(Hanlim_Guideok3_geodf.geometry,
#                style_function= lambda x : {'fillColor':'green', 'fill_opacity':0.1, 'color':'green', 'weight':1.5}
#               ).add_to(map)

# folium.GeoJson(han3_geodf.geometry,
#                style_function= lambda x : {'fillColor':'yellow', 'fill_opacity':0.1, 'color':'yellow', 'weight':1.5}
#               ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
yongsu = geodf[geodf['PNU'] // 10**9 == 5011031022].reset_index(drop = True)
yongsu
# Out:
#                       PNU     JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0     5011031022135230003  3523-3 임    1   987750      50110
# 1     5011031022115740008  1574-8 대    1  2531425      50110
# 2     5011031022113960000     1396임    1  2531417      50110
# 3     5011031022135140001  3514-1 대    1  2531426      50110
# 4     5011031022136440005  3644-5 대    1  2531427      50110
# ...                   ...       ...  ...      ...        ...
# 9020  5011031022113540001  1354-1 대    1  2537316      50110
# 9021  5011031022135150000     3515전    1  2527645      50110
# 9022  5011031022135150003  3515-3 전    1  2527646      50110
# 9023  5011031022132620001  3262-1 답    1  2527938      50110
# 9024  5011031022132490001  3249-1 대    1  2528097      50110
#
#                                                geometry
# 0     POLYGON ((126.17364 33.32857, 126.17335 33.328...
# 1     POLYGON ((126.17471 33.32910, 126.17477 33.329...
# 2     POLYGON ((126.17832 33.33795, 126.17839 33.338...
# ...

# %%
yongsu_yongsu =  Entire_Viliage[['용수리']]
yongsu_yongdang =  Entire_Viliage[['용당리']]
yongsu_yongsu
# Out:
#             용수리
# 0    43270000.0
# 1    34390000.0
# 2    43730000.0
# 3    43930000.0
# 4    41400000.0
# ..          ...
# 565         NaN
# 566         NaN
# 567         NaN
# 568         NaN
# 569         NaN
#
# [570 rows x 1 columns]

# %%
yongsu_yongsulist = []
yongsu_yongdanglist = []

for j in range(len(yongsu)):
    for i in range(len(yongsu_yongsu)):
        if yongsu['PNU'][j] % 10**8 == yongsu_yongsu['용수리'][i]:
            yongsu_yongsulist.append(yongsu.loc[j][:])
            
for j in range(len(yongsu)):
    for i in range(len(yongsu_yongdang)):
        if yongsu['PNU'][j] % 10**8 == yongsu_yongdang['용당리'][i]:
            yongsu_yongdanglist.append(yongsu.loc[j][:])

# %%
len(yongsu_yongdanglist)
# Out:
# 63

# %%
yongsu_yongsulistdf = gpd.GeoDataFrame(yongsu_yongsulist, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
yongsu_yongdanglistdf = gpd.GeoDataFrame(yongsu_yongdanglist, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
yongsu_yongdanglistdf
# Out:
#                     PNU    JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0   5011031022110540000    1054대    1  1022193      50110
# 1   5011031022109950000    995 도    1  1074365      50110
# 2   5011031022110000000   1000 도    1  1074368      50110
# 3   5011031022110170000    1017대    1  1149136      50110
# 4   5011031022111400000    1140대    1  1149163      50110
# ..                  ...      ...  ...      ...        ...
# 58  5011031022115090000   1509 대    1  1760689      50110
# 59  5011031022111280001  1128-1대    1  1149291      50110
# 60  5011031022111280000    1128대    1  1283318      50110
# 61  5011031022111280000    1128대    1  1283318      50110
# 62  5011031022128750000    2875전    1  2537711      50110
#
#                                              geometry
# 0   POLYGON ((126.18165 33.33367, 126.18165 33.333...
# 1   POLYGON ((126.18208 33.33313, 126.18217 33.333...
# 2   POLYGON ((126.18191 33.33329, 126.18194 33.333...
# ...

# %%
yongsu_yongsulistdf.to_file("마을 shp_old/용수리.shp")
yongsu_yongdanglistdf.to_file("마을 shp_old/용당리.shp")

# %%
yongsu_yongsulistdf_geodf = gpd.read_file('마을 shp_new/용수리.shp', encoding='cp949').set_crs('EPSG:4326')
yongsu_yongdanglistdf_geodf = gpd.read_file('마을 shp_new/용당리.shp', encoding='cp949').set_crs('EPSG:4326')

# %%
ri_geodf[ri_geodf['RI_NM'] == '용수리']
# Out:
#          RI_CD RI_NM  SGG_OID COL_ADM_SE    GID  \
# 56  5011031022   용수리      228      50110  15259
#
#                                              geometry
# 56  POLYGON ((126.16429 33.32378, 126.16417 33.323...

# %%
from folium.features import DivIcon
import folium

map = folium.Map(location=[33.412, 126.2712], tiles ='OpenStreetMap' ,zoom_start=15)
folium.GeoJson(ri_geodf.geometry.loc[56],
               style_function= lambda x : {'fillColor':'gray', 'fill_opacity':0.1, 'color':'gray', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(yongsu_yongsulistdf_geodf.geometry,
               style_function= lambda x : {'fillColor':'navy', 'fill_opacity':0.1, 'color':'navy', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(yongsu_yongdanglistdf_geodf.geometry,
               style_function= lambda x : {'fillColor':'red', 'fill_opacity':0.1, 'color':'red', 'weight':1.5}
              ).add_to(map)

# folium.GeoJson(Hanlim_Guideok3_geodf.geometry,
#                style_function= lambda x : {'fillColor':'green', 'fill_opacity':0.1, 'color':'green', 'weight':1.5}
#               ).add_to(map)

# folium.GeoJson(han3_geodf.geometry,
#                style_function= lambda x : {'fillColor':'yellow', 'fill_opacity':0.1, 'color':'yellow', 'weight':1.5}
#               ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
gosan = geodf[geodf['PNU'] // 10**9 == 5011031023].reset_index(drop = True)
gosan
# Out:
#                       PNU      JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0     5011031023134420016  3442-16 전    1   987779      50110
# 1     5011031023126000000      2600전    1   994022      50110
# 2     5011031023102570000      257 대    1  2534450      50110
# 3     5011031023102060002    206-2 도    1   992845      50110
# 4     5011031023102230002    223-2 전    1  1004062      50110
# ...                   ...        ...  ...      ...        ...
# 9249  5011031023106540000       654전    1  2528060      50110
# 9250  5011031023118740009   1874-9 전    1  2528312      50110
# 9251  5011031023138230004   3823-4 전    1  2528298      50110
# 9252  5011031023118740018  1874-18 전    1  2528313      50110
# 9253  5011031023138230001   3823-1 대    1  2528361      50110
#
#                                                geometry
# 0     POLYGON ((126.16869 33.29463, 126.16874 33.294...
# 1     POLYGON ((126.17862 33.30926, 126.17890 33.309...
# ...

# %%
gosan1 =  Entire_Viliage[['고산1리']]
gosan2 =  Entire_Viliage[['고산2리']]
gosan2
# Out:
#            고산2리
# 0    18850000.0
# 1    22170000.0
# 2    21690000.0
# 3    21170000.0
# 4    20620001.0
# ..          ...
# 565         NaN
# 566         NaN
# 567         NaN
# 568         NaN
# 569         NaN
#
# [570 rows x 1 columns]

# %%
gosan1list = []
gosan2list = []

for j in range(len(gosan)):
    for i in range(len(gosan1)):
        if gosan['PNU'][j] % 10**8 == gosan1['고산1리'][i]:
            gosan1list.append(gosan.loc[j][:])
            
for j in range(len(gosan)):
    for i in range(len(gosan2)):
        if gosan['PNU'][j] % 10**8 == gosan2['고산2리'][i]:
            gosan2list.append(gosan.loc[j][:])

# %%
len(gosan2list)
# Out:
# 98

# %%
gosan1listtdf = gpd.GeoDataFrame(gosan1list, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
gosan2listtdf = gpd.GeoDataFrame(gosan2list, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
gosan2listtdf
# Out:
#                     PNU    JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0   5011031023102680000     268대    1  1091312      50110
# 1   5011031023116230003  1623-3대    1  1091836      50110
# 2   5011031023119510000    1951대    1  1091869      50110
# 3   5011031023119860000    1986대    1  1092163      50110
# 4   5011031023120550000   2055 도    1  1092419      50110
# ..                  ...      ...  ...      ...        ...
# 93  5011031023120460000   2046 창    1  2218801      50110
# 94  5011031023102690000     269대    1  2393846      50110
# 95  5011031023116970000   1697 대    1  2399633      50110
# 96  5011031023116970000   1697 대    1  2399633      50110
# 97  5011031023120420000    2042대    1  2532217      50110
#
#                                              geometry
# 0   POLYGON ((126.19576 33.29774, 126.19579 33.297...
# 1   POLYGON ((126.19308 33.30157, 126.19303 33.301...
# 2   POLYGON ((126.18992 33.30221, 126.18989 33.302...
# ...

# %%
gosan1listtdf.to_file("마을 shp_old/고산1리.shp")
gosan2listtdf.to_file("마을 shp_old/고산2리.shp")

# %%
gosan1listtdf_geodf = gpd.read_file('마을 shp_new/고산1리.shp', encoding='cp949').set_crs('EPSG:4326')
gosan2listtdf_geodf = gpd.read_file('마을 shp_new/고산2리.shp', encoding='cp949').set_crs('EPSG:4326')

# %%
ri_geodf[ri_geodf['RI_NM'] == '고산리']
# Out:
#          RI_CD RI_NM  SGG_OID COL_ADM_SE    GID  \
# 97  5011031023   고산리      265      50110  15300
#
#                                              geometry
# 97  MULTIPOLYGON (((126.16163 33.29187, 126.16168 ...

# %%
from folium.features import DivIcon
import folium

map = folium.Map(location=[33.412, 126.2712], tiles ='OpenStreetMap' ,zoom_start=15)
folium.GeoJson(ri_geodf.geometry.loc[97],
               style_function= lambda x : {'fillColor':'gray', 'fill_opacity':0.1, 'color':'gray', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(gosan1listtdf_geodf.geometry,
               style_function= lambda x : {'fillColor':'navy', 'fill_opacity':0.1, 'color':'navy', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(gosan2listtdf_geodf.geometry,
               style_function= lambda x : {'fillColor':'red', 'fill_opacity':0.1, 'color':'red', 'weight':1.5}
              ).add_to(map)

# folium.GeoJson(Hanlim_Guideok3_geodf.geometry,
#                style_function= lambda x : {'fillColor':'green', 'fill_opacity':0.1, 'color':'green', 'weight':1.5}
#               ).add_to(map)

# folium.GeoJson(han3_geodf.geometry,
#                style_function= lambda x : {'fillColor':'yellow', 'fill_opacity':0.1, 'color':'yellow', 'weight':1.5}
#               ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
josu = geodf[geodf['PNU'] // 10**9 == 5011031026].reset_index(drop = True)
josu
# Out:
#                       PNU      JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0     5011031026122650001   2265-1 전    1  2528518      50110
# 1     5011031026122650002   2265-2 전    1  2528520      50110
# 2     5011031026122650003   2265-3 전    1  2528522      50110
# 3     5011031026122650004   2265-4 전    1  2528523      50110
# 4     5011031026122650000      2265전    1  2528516      50110
# ...                   ...        ...  ...      ...        ...
# 8163  5011031026128110014  2811-14 전    1  2528061      50110
# 8164  5011031026131030000      3103전    1  2528136      50110
# 8165  5011031026131030001   3103-1 전    1  2528137      50110
# 8166  5011031026103550007    355-7 대    1  2528270      50110
# 8167  5011031026103550012   355-12 전    1  2528219      50110
#
#                                                geometry
# 0     POLYGON ((126.21520 33.32526, 126.21517 33.325...
# 1     POLYGON ((126.21502 33.32561, 126.21502 33.325...
# ...

# %%
josu1 =  Entire_Viliage[['조수1리']]
josu2 =  Entire_Viliage[['조수2리']]
josu2
# Out:
#            조수2리
# 0    37360000.0
# 1    37380003.0
# 2    37390003.0
# 3    37340002.0
# 4    37340004.0
# ..          ...
# 565         NaN
# 566         NaN
# 567         NaN
# 568         NaN
# 569         NaN
#
# [570 rows x 1 columns]

# %%
josu1list = []
josu2list = []

for j in range(len(josu)):
    for i in range(len(josu1)):
        if josu['PNU'][j] % 10**8 == josu1['조수1리'][i]:
            josu1list.append(josu.loc[j][:])
            
for j in range(len(josu)):
    for i in range(len(josu2)):
        if josu['PNU'][j] % 10**8 == josu2['조수2리'][i]:
            josu2list.append(josu.loc[j][:])

# %%
len(josu2list)
# Out:
# 41

# %%
josu1listdf = gpd.GeoDataFrame(josu1list, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
josu2listdf = gpd.GeoDataFrame(josu2list, columns = ['PNU', 'JIBUN', 'BCHK', 'SGG_OID', 'COL_ADM_SE', 'geometry']).reset_index(drop = True)
josu2listdf
# Out:
#                     PNU      JIBUN BCHK  SGG_OID COL_ADM_SE  \
# 0   5011031026140340005   4034-5 임    1  1002979      50110
# 1   5011031026140070013  4007-13 대    1  2251361      50110
# 2   5011031026141180001   4118-1 과    1  1069997      50110
# 3   5011031026137380003    3738-3대    1  1103439      50110
# 4   5011031026139660002    3966-2전    1  1103254      50110
# 5   5011031026139660003    3966-3전    1  1103256      50110
# 6   5011031026140070005   4007-5 대    1  1103262      50110
# 7   5011031026139760008    3976-8전    1  1103273      50110
# 8   5011031026139730003    3973-3대    1  1103274      50110
# 9   5011031026139620001    3962-1전    1  1103301      50110
# 10  5011031026137400001    3740-1대    1  1103318      50110
# 11  5011031026137400002    3740-2도    1  1103332      50110
# 12  5011031026139610002    3961-2전    1  1103157      50110
# 13  5011031026137740012   3774-12전    1  1103360      50110
# 14  5011031026139580001    3958-1대    1  1103166      50110
# ...

# %%
josu1listdf.to_file("마을 shp_old/조수1리.shp")
josu2listdf.to_file("마을 shp_old/조수2리.shp")

# %%
josu1listdf_geodf = gpd.read_file('마을 shp_new/조수1리.shp', encoding='cp949').set_crs('EPSG:4326')
josu2listdf_geodf = gpd.read_file('마을 shp_new/조수2리.shp', encoding='cp949').set_crs('EPSG:4326')

# %%
ri_geodf[ri_geodf['RI_NM'] == '조수리']
# Out:
#          RI_CD RI_NM  SGG_OID COL_ADM_SE    GID  \
# 63  5011031026   조수리      221      50110  15266
#
#                                              geometry
# 63  POLYGON ((126.20411 33.32050, 126.20420 33.320...

# %%
from folium.features import DivIcon
import folium

map = folium.Map(location=[33.412, 126.2712], tiles ='OpenStreetMap' ,zoom_start=15)
folium.GeoJson(ri_geodf.geometry.loc[63],
               style_function= lambda x : {'fillColor':'gray', 'fill_opacity':0.1, 'color':'gray', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(josu1listdf_geodf.geometry,
               style_function= lambda x : {'fillColor':'navy', 'fill_opacity':0.1, 'color':'navy', 'weight':1.5}
              ).add_to(map)

folium.GeoJson(josu2listdf_geodf.geometry,
               style_function= lambda x : {'fillColor':'red', 'fill_opacity':0.1, 'color':'red', 'weight':1.5}
              ).add_to(map)

# folium.GeoJson(Hanlim_Guideok3_geodf.geometry,
#                style_function= lambda x : {'fillColor':'green', 'fill_opacity':0.1, 'color':'green', 'weight':1.5}
#               ).add_to(map)

# folium.GeoJson(han3_geodf.geometry,
#                style_function= lambda x : {'fillColor':'yellow', 'fill_opacity':0.1, 'color':'yellow', 'weight':1.5}
#               ).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...
